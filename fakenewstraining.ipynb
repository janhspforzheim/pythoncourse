# %% [markdown]
# #Dataset Merging

# %%
import pandas as pd

# %% [markdown]
# ##1. Load all 5 data sets and see which attributes are frequently represented in the data sets

# %%
#Load dataset 1 "Fake and real news dataset" (consisting of 2 separate data sets "True" and "False")
fake_1 = pd.read_csv('Fake1.csv')
true_1 = pd.read_csv('True1.csv')

#Show dataset
fake_1.head()
true_1.head()

#Column names
fake_1.columns
true_1.columns

#Data types of the columns
fake_1.dtypes
true_1.dtypes
# Out:
# title      object
# text       object
# subject    object
# date       object
# dtype: object

# %%
#Load dataset 2 "Fake News" 
dataset_2 = pd.read_csv('Dataset 2_Fake News.csv')

#Show dataset
dataset_2.head()

#Column names
dataset_2.columns

#Data types of the columns
dataset_2.dtypes
# Out:
# Unnamed: 0     int64
# title         object
# text          object
# label         object
# dtype: object

# %%
#Load dataset 3 "Sourced based Fake News Classification"
dataset_3 = pd.read_csv('Dataset 3_Sourced based Fake News Classification.csv')

#Show dataset
dataset_3.head()

#Column names
dataset_3.columns

#Data types of the columns
dataset_3.dtypes
# Out:
# author                      object
# published                   object
# title                       object
# text                        object
# language                    object
# site_url                    object
# main_img_url                object
# type                        object
# label                       object
# title_without_stopwords     object
# text_without_stopwords      object
# hasImage                   float64
# dtype: object

# %%
#Load dataset 4 "Fake news detection"
dataset_4 = pd.read_csv('Dataset 4_Fake news detection.csv')

#Show dataset
dataset_4.head()

#Column names
dataset_4.columns

#Data types of the columns
dataset_4.dtypes
# Out:
# URLs        object
# Headline    object
# Body        object
# Label        int64
# dtype: object

# %%
#Error!
#Load dataset 5 "Fake News Dataset"  
#dataset_5 = pd.read_csv('Dataset 5_Fake News Dataset.csv')

#Show dataset
#dataset_5.head()

#Column names
#dataset_5.columns

#Data types of the columns
#dataset_5.dtypes

# %% [markdown]
# All datasets contain the attributes title and text. Also, dataset 1 and dataset 3 both have date attributes.

# %% [markdown]
# ##2. Uniform column names for the same column contents

# %%
# "title" as column name for the articles title
# "text" as column name for the article content
# "date" as column name for the publishing date
# "label" as column name for the label 

#rename columns of dataset 4
dataset_4 = dataset_4.rename(columns={'Headline': 'title', 'Body': 'text', 'Label':'label'})
dataset_4.columns

#rename column of dataset 3
dataset_3 = dataset_3.rename(columns={'published': 'date'})
dataset_3.columns
dataset_3.head()
# Out:
#                  author                           date  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  muslims busted they stole millions in govt ben...
# 1  re why did attorney general loretta lynch plea...
# 2  breaking weiner cooperating with fbi on hillar...
# 3  pin drop speech by father of daughter kidnappe...
# 4  fantastic trumps  point plan to reform healthc...
#
#                                                 text language  \
# 0  print they should pay all the back all the mon...  english
# 1  why did attorney general loretta lynch plead t...  english
# 2  red state  \nfox news sunday reported this mor...  english
# ...

# %% [markdown]
# **to do: use same format for date columns in dataset 1 and dataset 3!**

# %% [markdown]
# ##3. Merge two separate datasets from dataset 1 into one

# %%
fake_1.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_1.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
# First add a column for the label
fake_1['label'] = 0
fake_1.head()

true_1['label']=1
true_1.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
#concat fake_1 and true_1 datasets
dataset_1 = pd.concat([fake_1, true_1], ignore_index=True, sort=False)
len(dataset_1)
dataset_1
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %% [markdown]
# ##4. Uniform labeling of true and fake news in the label column

# %% [markdown]
# Fake News = 0; True/Real News = 1

# %%
#dataset 2
dataset_2.label[dataset_2.label == 'FAKE'] = 0
dataset_2.label[dataset_2.label == 'REAL'] = 1
dataset_2

#dataset 3
dataset_3.label[dataset_3.label == 'Fake'] = 0
dataset_3.label[dataset_3.label == 'Real'] = 1
dataset_3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ##5.Drop unusuable columns and save dataframes under a new name

# %%
#dataset 1: drop subject column and subject+date columns
dataset_1_withdate= dataset_1.drop(['subject'], 1)
dataset_1_withdate.head()

dataset_1_nodate =dataset_1.drop(['subject','date'], 1)
dataset_1_nodate.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# ...

# %%
#dataset 2: drop column "Unnamed: 0"
dataset_2_new= dataset_2.drop(['Unnamed: 0'], 1)
dataset_2_new.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...     0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...     0
# 2  U.S. Secretary of State John F. Kerry said Mon...     1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...     0
# 4  It's primary day in New York and front-runners...     1

# %%
#dataset 3: drop columns 'author', 'date', 'title', 'text', 'language', 'site_url', 'main_img_url', 'type', 'label', 'title_without_stopwords','text_without_stopwords', 'hasImage'
dataset_3_withdate= dataset_3.drop(['author','language','site_url','main_img_url','type','title_without_stopwords','text_without_stopwords','hasImage'], 1)
dataset_3_nodate= dataset_3.drop(['author','date','language','site_url','main_img_url','type','title_without_stopwords','text_without_stopwords','hasImage'], 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
#                                                title  \
# 0  muslims busted they stole millions in govt ben...
# 1  re why did attorney general loretta lynch plea...
# 2  breaking weiner cooperating with fbi on hillar...
# 3  pin drop speech by father of daughter kidnappe...
# 4  fantastic trumps  point plan to reform healthc...
#
#                                                 text label
# 0  print they should pay all the back all the mon...     1
# ...

# %%
#dataset 4: drop column 'URLs'
dataset_4_new= dataset_4.drop(['URLs'], 1)
dataset_4_new.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#                                                title  \
# 0         Four ways Bob Corker skewered Donald Trump
# 1  Linklater's war veteran comedy speaks to moder...
# 2  Trump’s Fight With Corker Jeopardizes His Legi...
# 3  Egypt's Cheiron wins tie-up with Pemex for Mex...
# 4        Jason Aldean opens 'SNL' with Vegas tribute
#
#                                                 text  label
# 0  Image copyright Getty Images\nOn Sunday mornin...      1
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1
# 2  The feud broke into public view last week when...      1
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1
# 4  Country singer Jason Aldean, who was performin...      1

# %% [markdown]
# ##6. Merge datasets

# %% [markdown]
# The next step is to merge two data sets at a time. This results in various combinations of data sets.

# %%
#Merge dataset_1_withdate & dataset_3_withdate
dataset_3_4_withdate = pd.concat([dataset_1_withdate, dataset_3_withdate], ignore_index=True, sort=False)
dataset_3_4_withdate.isna().sum()
# Out:
# title     0
# text     46
# date      0
# label     1
# dtype: int64

# %%
#Merge dataset_1_nodate & dataset_2_new
dataset_1_2 = pd.concat([dataset_1_nodate, dataset_2_new], ignore_index=True, sort=False)
dataset_1_2
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 51228  State Department says it can't find emails fro...
# 51229  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 51230  Anti-Trump Protesters Are Tools of the Oligarc...
# 51231  In Ethiopia, Obama seeks progress on peace, se...
# 51232  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                     text label
# 0      Donald Trump just couldn t wish all Americans ...     0
# 1      House Intelligence Committee Chairman Devin Nu...     0
# 2      On Friday, it was revealed that former Milwauk...     0
# ...

# %%
#Merge dataset_1_nodate & dataset_3_nodate
dataset_1_3 = pd.concat([dataset_1_nodate, dataset_3_nodate], ignore_index=True, sort=False)
dataset_1_3
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 46989          teens walk free after gangrape conviction
# 46990         school named for munichmassacre mastermind
# 46991                      russia unveils satan  missile
# 46992              check out hillarythemed haunted house
# 46993  cannabis aficionados develop thca crystalline ...
#
#                                                     text label
# 0      Donald Trump just couldn t wish all Americans ...     0
# 1      House Intelligence Committee Chairman Devin Nu...     0
# 2      On Friday, it was revealed that former Milwauk...     0
# ...

# %%
#Merge dataset_1_nodate & dataset_4_new
dataset_1_4 = pd.concat([dataset_1_nodate, dataset_4_new], ignore_index=True, sort=False)
dataset_1_4
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 48902                                    Trends to Watch
# 48903  Trump Jr. Is Soon To Give A 30-Minute Speech F...
# 48904        Ron Paul on Trump, Anarchism & the AltRight
# 48905  China to accept overseas trial data in bid to ...
# 48906  Vice President Mike Pence Leaves NFL Game Beca...
#
#                                                     text  label
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# ...

# %%
#Merge dataset_2_new & dataset_3_nodate
dataset_2_3 = pd.concat([dataset_2_new, dataset_3_nodate], ignore_index=True, sort=False)
dataset_2_3
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 8426          teens walk free after gangrape conviction
# 8427         school named for munichmassacre mastermind
# 8428                      russia unveils satan  missile
# 8429              check out hillarythemed haunted house
# 8430  cannabis aficionados develop thca crystalline ...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...     0
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...     0
# 2     U.S. Secretary of State John F. Kerry said Mon...     1
# ...

# %%
#Merge dataset_2_new & dataset_4_new
dataset_2_4 = pd.concat([dataset_2_new, dataset_4_new], ignore_index=True, sort=False)
dataset_2_4
# Out:
#                                                    title  \
# 0                           You Can Smell Hillary’s Fear
# 1      Watch The Exact Moment Paul Ryan Committed Pol...
# 2            Kerry to go to Paris in gesture of sympathy
# 3      Bernie supporters on Twitter erupt in anger ag...
# 4       The Battle of New York: Why This Primary Matters
# ...                                                  ...
# 10339                                    Trends to Watch
# 10340  Trump Jr. Is Soon To Give A 30-Minute Speech F...
# 10341        Ron Paul on Trump, Anarchism & the AltRight
# 10342  China to accept overseas trial data in bid to ...
# 10343  Vice President Mike Pence Leaves NFL Game Beca...
#
#                                                     text label
# 0      Daniel Greenfield, a Shillman Journalism Fello...     0
# 1      Google Pinterest Digg Linkedin Reddit Stumbleu...     0
# 2      U.S. Secretary of State John F. Kerry said Mon...     1
# ...

# %%
#Merge dataset_3_nodate & dataset_4_new
dataset_3_4 = pd.concat([dataset_3_nodate, dataset_4_new], ignore_index=True, sort=False)
dataset_3_4

# %% [markdown]
# #Data Cleansing

# %%
#suche nach spalten in denen nur leerzeichen im feld text stehen
all_data['text_isSpace'] = list(map(lambda x: x.isspace(), all_data['text']))
#lösche die zeilen in denen nur leerzeichen im text feld stehen
all_data= all_data[all_data['text_isSpace'] == False]

#spalte text_isSpace wider löschen
all_data = all_data.drop(columns=['text_isSpace'], axis=1)

# %%
#finde werte bei denen title und date gleich sind und lösche sie
all_data = all_data.loc[all_data['title']!= all_data['date']]

# %%
#Ergebnisse finden bei denen der Tittel länger ist als der Text
all_data.loc[all_data['title'].str.len() > all_data['text'].str.len()]
# Out:
#                                                    title  \
# 11117  MY FAVORITE EXCUSES…Featuring Hillary Rotten C...
# 11251  MELANIA TRUMP GIVES POWERFUL SPEECH to Honor ‘...
# 11286  TERRORISM EXPERT SEBASTIAN GORKA On What Next ...
# 11288  TRUMP CABINET MEMBER MICK MULVANEY ON DC: “Thi...
# 11315  CRYBABY NANCY PELOSI Taunts Trump On Healthcar...
# ...                                                  ...
# 21645  (Video) Obama Supporters Sign Petition to NUKE...
# 21659  [Video] AWESOME: TEXAS MOM FRUSTRATED BY MCKIN...
# 21789  (VIDEO) ALAN DERSHOWITZ – SAD DAY FOR JUSTICE ...
# 21868  THIS IS GREAT! ANTI-HILLARY STREET ART POPS UP...
# 21882  ONLY IN DETROIT: SQUATTING ON THE SQUATTER TAK...
#
#                                                     text    subject  \
# 11117                                             Enjoy:   politics
# 11251        https://www.youtube.com/watch?v=cJZFepSvxzM   politics
# 11286        https://www.youtube.com/watch?v=-7Tn4gi_Os8   politics
# ...

# %%
#manche Texte enthalten nur ein Link zu z.B einem Youtube video. Manchmal wird aber auch nur auf etwas anderes verlinkt, zusätzlich zum text. Filterd etwas schwieriger
all_data.loc[all_data.text.str.contains('http')]
# Out:
#                                                    title  \
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 16      The Internet Brutally Mocks Disney’s New Trum...
# 19      Republican Senator Gets Dragged For Going Aft...
# 27      WATCH: Fox Host Calls For A ‘Cleansing’ Of Th...
# ...                                                  ...
# 23426  BOMBSHELL: Classified NATO Report Praises Russ...
# 23440  Watch as Trump Gatecrashes Glenn Beck’s Cruz C...
# 23463  Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23465  ‘There’ll be boots on the ground’: US making n...
# 23479  How to Blow $700 Million: Al Jazeera America F...
#
#                                                     text      subject  \
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# ...

# %%
#Finde alle Zeilen in denen das Datum NICHT diesen String enthält
all_data.loc[~all_data.date.str.contains(', 20')]
#Lösche alle Zeilen die den String nicht enthalten
all_data = all_data.loc[all_data.date.str.contains(', 20')]

# %%
# finde besonders kurze texte
all_data.loc[all_data['text'].str.len() < 20]

#Löschen?
# all_data = all_data.loc[~all_data['text'].str.len() < 20]
# Out:
#                                                    title                 text  \
# 11117  MY FAVORITE EXCUSES…Featuring Hillary Rotten C...               Enjoy:
# 11324  HYSTERICAL! HERE’S WHY TRUMP SAID TO REPORTER:...         Read more:WT
# 11447  HOMELAND SECURITY Catering to Illegals? Three ...       Read more: TMZ
# 11517  MULTI-MILLIONAIRE Global-Warming Hypocrites LE...               Enjoy:
# 11685  ARROGANT ILLEGAL ALIEN Who Voted 5 Times In 20...               Watch:
# 11796  TRUMP’S BRILLIANT Director Of Communications O...              Watch:
# 11829  WATCH! Anti-Trump Hag Gets Kicked Off Flight A...  Via: GATEWAY PUNDIT
# 11847  BREAKING: PRESIDENT TRUMP Signs Most Important...             Via: NPR
# 11978  DELUSIONAL DEMOCRATS Get A Reality Check: “No,...           Via: MRCTV
# 12012  PELOSI Lied About “Affordable” Healthcare And ...              Via: WT
# 12063  OUCH! Paul Joseph Watson DESTROYS MTV’s Racist...               Enjoy
# ...

# %%
#Kurze Titel finden, Wahrscheinlich nicht löschen?
all_data.loc[all_data['title'].str.len() < 20]
# Out:
#                      title                                               text  \
# 14960      JOKE OF THE DAY  My wife and I went into town and visited a sho...
# 21228    No Words… [VIDEO]  For the first time in the history of 100% FED ...
# 22064  Boiler Room EP #118  Tune in to the Alternate Current Radio Network...
# 22330   Boiler Room EP #87  Tune in to the Alternate Current Radio Network...
# 22448   Boiler Room EP #78  Tune in to the Alternate Current Radio Network...
# 22847  Boiler Room EP #118  Tune in to the Alternate Current Radio Network...
# 23113   Boiler Room EP #87  Tune in to the Alternate Current Radio Network...
# 23231   Boiler Room EP #78  Tune in to the Alternate Current Radio Network...
#
#            subject              date  Echt
# 14960     politics       Nov 7, 2015     0
# 21228    left-news      Dec 12, 2015     0
# 22064      US_News     July 20, 2017     0
# 22330      US_News  December 8, 2016     0
# 22448      US_News  October 12, 2016     0
# ...

# %% [markdown]
# #Training

# %%
fake =  pd.read_csv('data\Fake.csv')
true = pd.read_csv('data\True.csv')

# %%
#wie viele Datensätze haben ein Leerzeichen im text (oder zwei)
fake.loc[fake['text'] ==' '].count() + fake.loc[fake['text'] =='  '].count()

# %%
#suche Nach datensatz mit disem Titel
fake.loc[fake['title'] == 'https://100percentfedup.com/served-roy-moore-vietnamletter-veteran-sets-record-straight-honorable-decent-respectable-patriotic-commander-soldier/']

# %%
#Nur das Datum ausgeben lassen
fake.date[9358]

# %%
#test
